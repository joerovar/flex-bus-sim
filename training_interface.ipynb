# %%
from rl_env import FlexSimEnv
import numpy as np
import pandas as pd

# %% [markdown]
# ## Training with best parameters

# %%
from training_claude import train_vehicles

# %%
# function to receive a float and return a string with '_' instead of '.'
def float_to_str(f):
    return str(f).replace('.', '_')

# %%
learning_rate = 6e-3
gamma = 0.995
n_steps = 16_000

reward_weights = [-2.7, -3.0, -3.2, -3.5, -3.8]
demand_scenario = ['peak', 'off_peak']

for i in range(len(reward_weights)):
    for j in range(len(demand_scenario)):
        model_path = f'models/{demand_scenario[j]}/dqn_{float_to_str(reward_weights[i])}.pth'
        train_vehicles(reward_weight=reward_weights[i], 
                    learning_rate=learning_rate,
                    gamma=gamma,
                    n_steps=n_steps,
                    save_path=model_path,
                    demand_scenario=demand_scenario[j],)
# Out:
# Training with shared policy...
#
# Training complete! Final average reward: -1.69
#
# Model saved as models/peak/dqn_-2_7.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.91
#
# Model saved as models/off_peak/dqn_-2_7.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.64
#
# Model saved as models/peak/dqn_-3_0.pth
# Training with shared policy...
#
# Training complete! Final average reward: -2.09
#
# Model saved as models/off_peak/dqn_-3_0.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.75
#
# Model saved as models/peak/dqn_-3_2.pth
# Training with shared policy...
#
# Training complete! Final average reward: -2.00
#
# Model saved as models/off_peak/dqn_-3_2.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.77
#
# Model saved as models/peak/dqn_-3_5.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.95
#
# Model saved as models/off_peak/dqn_-3_5.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.84
#
# Model saved as models/peak/dqn_-3_8.pth
# Training with shared policy...
#
# Training complete! Final average reward: -1.99
#
# Model saved as models/off_peak/dqn_-3_8.pth

# %% [markdown]
# ## Slope evaluations

# %%
from eval import evaluate_slopes

# %%
reward_weights = [-2.0, -2.5, -3.0]
slope_results = evaluate_slopes(reward_weights=reward_weights)
# Out:
# Evaluating slope 0.0, reward_weight -2.0
# Evaluating slope 0.0, reward_weight -2.5
# Evaluating slope 0.0, reward_weight -3.0
# Evaluating slope 0.5, reward_weight -2.0
# Evaluating slope 0.5, reward_weight -2.5
# Evaluating slope 0.5, reward_weight -3.0
# Evaluating slope 1.0, reward_weight -2.0
# Evaluating slope 1.0, reward_weight -2.5
# Evaluating slope 1.0, reward_weight -3.0
# Evaluating slope 1.5, reward_weight -2.0
# Evaluating slope 1.5, reward_weight -2.5
# Evaluating slope 1.5, reward_weight -3.0
# Evaluating slope 2.0, reward_weight -2.0
# Evaluating slope 2.0, reward_weight -2.5
# Evaluating slope 2.0, reward_weight -3.0
# Evaluating slope 2.5, reward_weight -2.0
# Evaluating slope 2.5, reward_weight -2.5
# Evaluating slope 2.5, reward_weight -3.0
# Evaluating slope 3.0, reward_weight -2.0
# Evaluating slope 3.0, reward_weight -2.5
# Evaluating slope 3.0, reward_weight -3.0

# %%
slope_df = pd.DataFrame(slope_results)

# %%
# pd.DataFrame(slope_results).sort_values(by=['slope','mean_reward'])

# %% [markdown]
# ## grid search

# %%
from training_claude import grid_search_dqn
import pandas as pd

# %%
grid_search_results = grid_search_dqn(
    lr_values=[6e-3], # learning rate
    n_steps_values=[12_000, 16_000, 18_000], # timesteps
    gamma_values=[0.985, 0.995], # discount factor
    reward_weights = [-2.7, -3.0, -3.2, -3.5, -3.8], # reward weights
    demand_scenarios=['peak', 'off_peak'],
    verbose=True
)
# Out:
# Training with shared policy...
#
# Training complete! Final average reward: -1.76
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-2.7 demand_scenario=peak
# Reward: -1.653 +/- 2.029
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.91
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-2.7 demand_scenario=off_peak
# Reward: -0.936 +/- 1.603
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.70
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.0 demand_scenario=peak
# Reward: -1.04 +/- 1.601
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.94
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.0 demand_scenario=off_peak
# Reward: -1.652 +/- 1.966
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.76
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.2 demand_scenario=peak
# Reward: -1.1 +/- 1.58
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.99
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.2 demand_scenario=off_peak
# Reward: -2.153 +/- 2.012
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.76
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.5 demand_scenario=peak
# Reward: -0.929 +/- 1.621
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.00
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.5 demand_scenario=off_peak
# Reward: -0.949 +/- 1.556
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.67
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.8 demand_scenario=peak
# Reward: -0.979 +/- 1.559
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.95
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.985, reward_weight=-3.8 demand_scenario=off_peak
# Reward: -1.005 +/- 1.757
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.79
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-2.7 demand_scenario=peak
# Reward: -1.767 +/- 1.97
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.03
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-2.7 demand_scenario=off_peak
# Reward: -0.975 +/- 1.546
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.82
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.0 demand_scenario=peak
# Reward: -1.513 +/- 1.964
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.01
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.0 demand_scenario=off_peak
# Reward: -0.984 +/- 1.623
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.75
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.2 demand_scenario=peak
# Reward: -1.446 +/- 1.962
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.96
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.2 demand_scenario=off_peak
# Reward: -0.991 +/- 1.611
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.88
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.5 demand_scenario=peak
# Reward: -1.351 +/- 1.84
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.91
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.5 demand_scenario=off_peak
# Reward: -1.804 +/- 1.927
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.77
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.8 demand_scenario=peak
# Reward: -1.737 +/- 2.109
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.90
#
# Evaluation summary:
# Params: lr=0.006, n_steps=12000, gamma=0.995, reward_weight=-3.8 demand_scenario=off_peak
# Reward: -1.162 +/- 1.83
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.84
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-2.7 demand_scenario=peak
# Reward: -1.01 +/- 1.686
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.03
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-2.7 demand_scenario=off_peak
# Reward: -0.925 +/- 1.584
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.74
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.0 demand_scenario=peak
# Reward: -2.024 +/- 2.011
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.17
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.0 demand_scenario=off_peak
# Reward: -1.172 +/- 1.915
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.75
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.2 demand_scenario=peak
# Reward: -1.377 +/- 1.896
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.79
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.2 demand_scenario=off_peak
# Reward: -1.359 +/- 1.936
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.82
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.5 demand_scenario=peak
# Reward: -1.066 +/- 1.693
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.95
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.5 demand_scenario=off_peak
# Reward: -2.093 +/- 2.0
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.65
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.8 demand_scenario=peak
# Reward: -1.358 +/- 1.921
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.92
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.985, reward_weight=-3.8 demand_scenario=off_peak
# Reward: -1.082 +/- 1.718
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.76
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-2.7 demand_scenario=peak
# Reward: -0.984 +/- 1.669
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.12
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-2.7 demand_scenario=off_peak
# Reward: -1.96 +/- 2.001
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.85
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.0 demand_scenario=peak
# Reward: -1.992 +/- 2.009
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.01
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.0 demand_scenario=off_peak
# Reward: -1.256 +/- 1.869
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.77
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.2 demand_scenario=peak
# Reward: -1.25 +/- 1.841
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.98
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.2 demand_scenario=off_peak
# Reward: -0.918 +/- 1.619
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.76
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.5 demand_scenario=peak
# Reward: -0.862 +/- 1.541
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.90
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.5 demand_scenario=off_peak
# Reward: -0.972 +/- 1.541
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.89
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.8 demand_scenario=peak
# Reward: -1.029 +/- 1.672
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.82
#
# Evaluation summary:
# Params: lr=0.006, n_steps=16000, gamma=0.995, reward_weight=-3.8 demand_scenario=off_peak
# Reward: -0.997 +/- 1.638
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.94
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-2.7 demand_scenario=peak
# Reward: -0.997 +/- 1.598
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.02
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-2.7 demand_scenario=off_peak
# Reward: -1.116 +/- 1.61
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.90
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.0 demand_scenario=peak
# Reward: -1.732 +/- 2.065
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.96
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.0 demand_scenario=off_peak
# Reward: -1.663 +/- 2.054
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.77
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.2 demand_scenario=peak
# Reward: -1.257 +/- 1.881
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -2.01
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.2 demand_scenario=off_peak
# Reward: -0.989 +/- 1.577
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.68
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.5 demand_scenario=peak
# Reward: -1.246 +/- 1.805
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.84
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.5 demand_scenario=off_peak
# Reward: -1.487 +/- 2.002
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.79
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.8 demand_scenario=peak
# Reward: -1.388 +/- 2.02
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.94
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.985, reward_weight=-3.8 demand_scenario=off_peak
# Reward: -1.075 +/- 1.743
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.68
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-2.7 demand_scenario=peak
# Reward: -0.927 +/- 1.491
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.96
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-2.7 demand_scenario=off_peak
# Reward: -1.353 +/- 1.922
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.68
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.0 demand_scenario=peak
# Reward: -1.333 +/- 2.008
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.92
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.0 demand_scenario=off_peak
# Reward: -1.106 +/- 1.789
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.88
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.2 demand_scenario=peak
# Reward: -1.222 +/- 1.954
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.93
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.2 demand_scenario=off_peak
# Reward: -1.038 +/- 1.728
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.82
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.5 demand_scenario=peak
# Reward: -2.185 +/- 2.028
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.87
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.5 demand_scenario=off_peak
# Reward: -0.896 +/- 1.598
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.75
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.8 demand_scenario=peak
# Reward: -2.094 +/- 2.063
# ------------------------
# Training with shared policy...
#
# Training complete! Final average reward: -1.87
#
# Evaluation summary:
# Params: lr=0.006, n_steps=18000, gamma=0.995, reward_weight=-3.8 demand_scenario=off_peak
# Reward: -1.357 +/- 1.89
# ------------------------

# %%
grid_search_df = pd.DataFrame(grid_search_results)

# %%
grid_search_df.groupby(['demand_scenario'])['avg_picked_requests'].describe()
# Out:
#                  count      mean       std  min    25%  50%  75%  max
# demand_scenario
# off_peak          30.0  1.696667  0.071840  1.6  1.625  1.7  1.7  1.8
# peak              30.0  1.686667  0.116658  1.4  1.600  1.7  1.7  2.0

# %%
grid_search_df.sort_values(by=['weight', 'demand_scenario','mean_reward'])
# Out:
#     weight     lr  n_steps  gamma demand_scenario  mean_reward  std_reward  \
# 59    -3.8  0.006    18000  0.995        off_peak       -1.357       1.890
# 19    -3.8  0.006    12000  0.995        off_peak       -1.162       1.830
# 29    -3.8  0.006    16000  0.985        off_peak       -1.082       1.718
# 49    -3.8  0.006    18000  0.985        off_peak       -1.075       1.743
# 9     -3.8  0.006    12000  0.985        off_peak       -1.005       1.757
# 39    -3.8  0.006    16000  0.995        off_peak       -0.997       1.638
# 58    -3.8  0.006    18000  0.995            peak       -2.094       2.063
# 18    -3.8  0.006    12000  0.995            peak       -1.737       2.109
# 48    -3.8  0.006    18000  0.985            peak       -1.388       2.020
# 28    -3.8  0.006    16000  0.985            peak       -1.358       1.921
# 38    -3.8  0.006    16000  0.995            peak       -1.029       1.672
# 8     -3.8  0.006    12000  0.985            peak       -0.979       1.559
# 27    -3.5  0.006    16000  0.985        off_peak       -2.093       2.000
# 17    -3.5  0.006    12000  0.995        off_peak       -1.804       1.927
# 47    -3.5  0.006    18000  0.985        off_peak       -1.487       2.002
# 37    -3.5  0.006    16000  0.995        off_peak       -0.972       1.541
# 7     -3.5  0.006    12000  0.985        off_peak       -0.949       1.556
# 57    -3.5  0.006    18000  0.995        off_peak       -0.896       1.598
# 56    -3.5  0.006    18000  0.995            peak       -2.185       2.028
# 16    -3.5  0.006    12000  0.995            peak       -1.351       1.840
# 46    -3.5  0.006    18000  0.985            peak       -1.246       1.805
# 26    -3.5  0.006    16000  0.985            peak       -1.066       1.693
# 6     -3.5  0.006    12000  0.985            peak       -0.929       1.621
# 36    -3.5  0.006    16000  0.995            peak       -0.862       1.541
# 5     -3.2  0.006    12000  0.985        off_peak       -2.153       2.012
# 25    -3.2  0.006    16000  0.985        off_peak       -1.359       1.936
# 55    -3.2  0.006    18000  0.995        off_peak       -1.038       1.728
# 15    -3.2  0.006    12000  0.995        off_peak       -0.991       1.611
# 45    -3.2  0.006    18000  0.985        off_peak       -0.989       1.577
# 35    -3.2  0.006    16000  0.995        off_peak       -0.918       1.619
# 14    -3.2  0.006    12000  0.995            peak       -1.446       1.962
# 24    -3.2  0.006    16000  0.985            peak       -1.377       1.896
# 44    -3.2  0.006    18000  0.985            peak       -1.257       1.881
# 34    -3.2  0.006    16000  0.995            peak       -1.250       1.841
# 54    -3.2  0.006    18000  0.995            peak       -1.222       1.954
# 4     -3.2  0.006    12000  0.985            peak       -1.100       1.580
# 43    -3.0  0.006    18000  0.985        off_peak       -1.663       2.054
# 3     -3.0  0.006    12000  0.985        off_peak       -1.652       1.966
# 33    -3.0  0.006    16000  0.995        off_peak       -1.256       1.869
# 23    -3.0  0.006    16000  0.985        off_peak       -1.172       1.915
# 53    -3.0  0.006    18000  0.995        off_peak       -1.106       1.789
# 13    -3.0  0.006    12000  0.995        off_peak       -0.984       1.623
# 22    -3.0  0.006    16000  0.985            peak       -2.024       2.011
# 32    -3.0  0.006    16000  0.995            peak       -1.992       2.009
# 42    -3.0  0.006    18000  0.985            peak       -1.732       2.065
# 12    -3.0  0.006    12000  0.995            peak       -1.513       1.964
# 52    -3.0  0.006    18000  0.995            peak       -1.333       2.008
# 2     -3.0  0.006    12000  0.985            peak       -1.040       1.601
# 31    -2.7  0.006    16000  0.995        off_peak       -1.960       2.001
# 51    -2.7  0.006    18000  0.995        off_peak       -1.353       1.922
# 41    -2.7  0.006    18000  0.985        off_peak       -1.116       1.610
# 11    -2.7  0.006    12000  0.995        off_peak       -0.975       1.546
# 1     -2.7  0.006    12000  0.985        off_peak       -0.936       1.603
# 21    -2.7  0.006    16000  0.985        off_peak       -0.925       1.584
# 10    -2.7  0.006    12000  0.995            peak       -1.767       1.970
# 0     -2.7  0.006    12000  0.985            peak       -1.653       2.029
# 20    -2.7  0.006    16000  0.985            peak       -1.010       1.686
# 40    -2.7  0.006    18000  0.985            peak       -0.997       1.598
# 30    -2.7  0.006    16000  0.995            peak       -0.984       1.669
# 50    -2.7  0.006    18000  0.995            peak       -0.927       1.491
#
#     deviation_opportunities  deviations  avg_picked_requests  early_trips  \
# 59                     54.2        39.6                  1.7         14.0
# 19                     54.2        41.3                  1.6         13.6
# 29                     54.4        37.9                  1.8         12.5
# 49                     56.3        38.5                  1.7         13.9
# 9                      55.0        40.9                  1.6         12.1
# 39                     56.5        38.4                  1.8         14.0
# 58                     46.6        44.9                  1.6         10.5
# 18                     51.6        38.7                  1.7         11.2
# 48                     54.5        45.6                  1.6         12.0
# 28                     57.3        40.7                  1.7         12.3
# 38                     58.3        35.4                  1.7         15.5
# 8                      58.0        32.0                  1.8         16.0
# 27                     46.4        46.5                  1.7          8.8
# 17                     62.9        15.6                  1.7         28.5
# 47                     51.3        39.4                  1.7         11.8
# 37                     57.4        31.8                  1.8         16.7
# 7                      59.3        33.3                  1.8         15.5
# 57                     57.0        37.2                  1.7         13.4
# 56                     64.7         9.7                  1.8         34.1
# 16                     58.5        35.6                  1.6         16.9
# 46                     50.8        41.5                  1.7         12.8
# 26                     58.6        35.3                  1.7         15.7
# 6                      57.4        38.2                  1.7         13.5
# 36                     55.9        38.2                  1.8         13.4
# 5                      46.2        45.1                  1.6          8.6
# 25                     55.5        43.9                  1.6         12.4
# 55                     54.8        40.1                  1.6         13.6
# 15                     57.9        34.4                  1.7         15.8
# 45                     57.7        34.6                  1.7         15.5
# 35                     57.7        36.1                  1.7         13.1
# 14                     54.0        40.3                  1.6         14.1
# 24                     55.2        39.1                  1.7         13.3
# 44                     56.1        42.3                  1.6         13.5
# 34                     54.6        39.7                  1.7         14.1
# 54                     53.6        43.4                  1.6         12.1
# 4                      58.7        27.1                  2.0         19.4
# 43                     52.2        46.0                  1.7         11.5
# 3                      43.7        42.1                  1.7         11.3
# 33                     55.8        40.1                  1.6         12.9
# 23                     53.4        42.7                  1.7         11.5
# 53                     56.9        41.3                  1.7         12.5
# 13                     57.6        36.1                  1.8         14.8
# 22                     55.3        26.4                  1.4         24.3
# 32                     47.0        45.5                  1.7          9.5
# 42                     58.2        24.0                  1.4         24.6
# 12                     48.2        42.6                  1.6         12.3
# 52                     53.4        45.5                  1.7         11.6
# 2                      57.1        30.4                  1.8         16.7
# 31                     45.9        46.2                  1.6          9.9
# 51                     56.1        39.4                  1.6         14.2
# 41                     59.5        29.1                  1.8         17.3
# 11                     59.4        32.2                  1.8         16.9
# 1                      56.3        34.9                  1.7         15.3
# 21                     57.1        37.6                  1.7         13.3
# 10                     48.0        43.6                  1.7         11.3
# 0                      50.6        39.3                  1.7         11.8
# 20                     56.4        37.4                  1.7         14.6
# 40                     56.8        35.1                  1.8         15.5
# 30                     57.5        38.2                  1.7         14.1
# 50                     57.2        33.3                  1.8         16.6
#
#     late_trips
# 59        16.3
# 19        12.5
# 29        11.3
# 49         9.8
# 9         10.5
# 39        10.1
# 58        34.6
# 18        25.5
# 48        18.4
# 28        16.5
# 38         6.1
# 8          4.0
# 27        34.9
# 17         1.2
# 47        21.0
# 37         3.3
# 7          5.1
# 57         5.0
# 56         1.0
# 16        12.6
# 46        15.8
# 26         7.6
# 6          6.0
# 36         6.9
# 5         35.0
# 25        17.9
# 55         9.3
# 15         3.7
# 45         5.6
# 35         6.0
# 14        17.8
# 24        16.7
# 44        14.8
# 34        14.2
# 54        13.9
# 4          3.4
# 43        26.0
# 3         24.8
# 33        14.6
# 23        14.0
# 53        11.2
# 13         6.6
# 22        12.6
# 32        32.2
# 42         3.7
# 12        20.9
# 52        17.1
# 2          3.7
# 31        33.0
# 51        15.2
# 41         2.5
# 11         3.3
# 1          4.5
# 21         6.7
# 10        28.0
# 0         23.6
# 20         7.8
# 40         6.8
# 30         7.0
# 50         3.3

# %%
grid_search_df = pd.DataFrame(grid_search_results)

# %%
grid_search_df.sort_values(by=['weight', 'mean_reward'])
# Out:
#     weight     lr  n_steps  gamma  mean_reward  std_reward  \
# 5     -3.5  0.006    12000  0.995       -1.357       1.978
# 17    -3.5  0.006    18000  0.995       -1.269       1.906
# 14    -3.5  0.006    18000  0.985       -1.222       1.818
# 11    -3.5  0.006    16000  0.995       -1.126       1.857
# 2     -3.5  0.006    12000  0.985       -0.936       1.552
# 8     -3.5  0.006    16000  0.985       -0.875       1.594
# 13    -3.2  0.006    18000  0.985       -1.323       2.001
# 4     -3.2  0.006    12000  0.995       -1.282       1.866
# 10    -3.2  0.006    16000  0.995       -1.219       1.872
# 1     -3.2  0.006    12000  0.985       -1.014       1.503
# 7     -3.2  0.006    16000  0.985       -0.937       1.581
# 16    -3.2  0.006    18000  0.995       -0.913       1.507
# 3     -3.0  0.006    12000  0.995       -1.934       1.985
# 12    -3.0  0.006    18000  0.985       -1.340       1.746
# 0     -3.0  0.006    12000  0.985       -1.337       1.709
# 6     -3.0  0.006    16000  0.985       -1.174       1.779
# 15    -3.0  0.006    18000  0.995       -1.030       1.616
# 9     -3.0  0.006    16000  0.995       -0.926       1.624
#
#     deviation_opportunities  deviations  avg_picked_requests  early_trips  \
# 5                      52.6        43.1                  1.6         13.6
# 17                     54.9        45.4                  1.6         11.9
# 14                     55.8        41.3                  1.6         12.8
# 11                     52.5        42.9                  1.6         12.0
# 2                      58.2        35.3                  1.7         15.0
# 8                      54.6        36.6                  1.7         14.0
# 13                     52.6        44.2                  1.6         12.6
# 4                      56.0        40.7                  1.7         13.9
# 10                     56.8        39.8                  1.7         13.8
# 1                      59.7        30.3                  1.8         18.4
# 7                      56.8        35.6                  1.7         14.7
# 16                     59.2        32.9                  1.7         15.1
# 3                      45.2        42.6                  1.7         11.0
# 12                     60.6        24.1                  1.7         21.0
# 0                      59.3        23.6                  1.7         21.4
# 6                      56.2        35.0                  1.6         15.9
# 15                     58.0        32.2                  1.7         15.5
# 9                      56.4        38.2                  1.8         14.2
#
#     late_trips
# 5         16.1
# 17        16.5
# 14        14.3
# 11        13.0
# 2          4.5
# 8          4.8
# 13        16.2
# 4         14.1
# 10        12.0
# 1          2.1
# 7          5.1
# 16         3.5
# 3         29.1
# 12         1.9
# 0          1.6
# 6          4.7
# 15         4.5
# 9          6.0

# %%
grid_search_df.sort_values(by=['weight', 'mean_reward'])
# Out:
#     weight     lr  n_steps  gamma  mean_reward  std_reward  \
# 5     -3.5  0.006    12000  0.995       -2.649       2.737
# 14    -3.5  0.006    18000  0.985       -2.643       2.725
# 17    -3.5  0.006    18000  0.995       -2.617       2.763
# 11    -3.5  0.006    16000  0.995       -1.333       2.194
# 2     -3.5  0.006    12000  0.985       -1.075       1.458
# 8     -3.5  0.006    16000  0.985       -0.897       1.564
# 16    -3.2  0.006    18000  0.995       -2.694       2.733
# 13    -3.2  0.006    18000  0.985       -2.648       2.539
# 1     -3.2  0.006    12000  0.985       -2.568       2.533
# 4     -3.2  0.006    12000  0.995       -2.533       2.577
# 7     -3.2  0.006    16000  0.985       -1.112       1.512
# 10    -3.2  0.006    16000  0.995       -0.922       1.453
# 12    -3.0  0.006    18000  0.985       -2.707       2.591
# 3     -3.0  0.006    12000  0.995       -2.682       2.408
# 9     -3.0  0.006    16000  0.995       -2.400       2.392
# 0     -3.0  0.006    12000  0.985       -1.285       1.475
# 6     -3.0  0.006    16000  0.985       -1.042       1.811
# 15    -3.0  0.006    18000  0.995       -0.881       1.437
#
#     deviation_opportunities  deviations  avg_picked_requests  early_trips  \
# 5                      38.7        38.7                  1.7          4.4
# 14                     39.6        39.6                  1.8          4.3
# 17                     43.8        41.9                  1.7          4.4
# 11                     56.2        43.6                  1.7          4.5
# 2                      60.8        25.6                  1.9          8.7
# 8                      58.7        34.5                  1.9          6.4
# 16                     41.4        35.3                  1.8          4.4
# 13                     37.6        37.6                  1.8          4.3
# 1                      40.7        40.7                  1.7          4.2
# 4                      44.6        41.8                  1.7          4.8
# 7                      60.3        25.2                  1.9          8.6
# 10                     58.5        30.9                  2.0          7.4
# 12                     46.2        38.5                  1.7          3.4
# 3                      40.2        39.1                  1.7          3.7
# 9                      41.1        39.8                  1.7          4.9
# 0                      62.7        19.5                  1.8         10.9
# 6                      54.9        42.6                  1.7          5.7
# 15                     60.0        32.6                  1.9          7.0
#
#     late_trips
# 5         49.1
# 14        48.2
# 17        51.4
# 11        25.3
# 2          3.0
# 8          8.1
# 16        52.9
# 13        52.4
# 1         53.4
# 4         56.1
# 7          3.9
# 10         7.4
# 12        62.2
# 3         56.8
# 9         52.6
# 0          2.4
# 6         20.2
# 15         6.7

# %%
grid_search_df.to_csv('outputs/grid_search_results.csv', index=False)

# %% [markdown]
# ## test default training

# %%
# train
from training_claude import train_vehicles

agent, scores = train_vehicles(reward_weights={'off_schedule_trips': -4.0, 'skipped_requests': -1.0})
# Out:
# Training with shared policy...
# Episode 0/500, Avg Score: -0.48, Epsilon: 1.0000
# Episode 20/500, Avg Score: -0.69, Epsilon: 0.8521
# Episode 40/500, Avg Score: -0.66, Epsilon: 0.7261
# Episode 60/500, Avg Score: -0.63, Epsilon: 0.6187
# Episode 80/500, Avg Score: -0.70, Epsilon: 0.5280
# Episode 100/500, Avg Score: -0.57, Epsilon: 0.4501
# Episode 120/500, Avg Score: -0.51, Epsilon: 0.3836
# Episode 140/500, Avg Score: -0.48, Epsilon: 0.3268
# Episode 160/500, Avg Score: -0.60, Epsilon: 0.2785
# Episode 180/500, Avg Score: -0.47, Epsilon: 0.2374
# Episode 200/500, Avg Score: -0.56, Epsilon: 0.2023
# Episode 220/500, Avg Score: -0.42, Epsilon: 0.1724
# Episode 240/500, Avg Score: -0.44, Epsilon: 0.1469
# Episode 260/500, Avg Score: -0.38, Epsilon: 0.1252
# Episode 280/500, Avg Score: -0.41, Epsilon: 0.1067
# Episode 300/500, Avg Score: -0.43, Epsilon: 0.0909
# Episode 320/500, Avg Score: -0.41, Epsilon: 0.0774
# Episode 340/500, Avg Score: -0.47, Epsilon: 0.0660
# Episode 360/500, Avg Score: -0.34, Epsilon: 0.0562
# Episode 380/500, Avg Score: -0.51, Epsilon: 0.0500
# Episode 400/500, Avg Score: -0.45, Epsilon: 0.0500
# Episode 420/500, Avg Score: -0.43, Epsilon: 0.0500
# Episode 440/500, Avg Score: -0.43, Epsilon: 0.0500
# Episode 460/500, Avg Score: -0.37, Epsilon: 0.0500
# Episode 480/500, Avg Score: -0.39, Epsilon: 0.0500
#
# Training complete! Final average reward: -0.40
# Model saved as 'shared_dqn_agent.pth'

# %% [markdown]
# ## TODO: turn this into a function that by control stop, and number of requests creates scatterplots for headway and schedule deviation

# %%
from training_claude import load_agent
import numpy as np

# Example of loading and using the model
loaded_agent = load_agent('shared_dqn_agent.pth')

# Example of getting an action from a state
# The state should be a dictionary with the expected keys
state = {
    "control_stop_idx": np.array([0]),      # Make sure this is an array
    "n_requests": np.array([2]),            # Make sure this is an array
    "headway": np.array([700.5]),            # Make sure this is an array
    "schedule_deviation": np.array([10])  # Make sure this is an array
}
vehicle_idx = 0  # Example vehicle index

# Get action from loaded model
action = loaded_agent.act(state, eval_mode=True)
print(f"For state {state}, the model recommends action: {action}")
# Out:
# For state {'control_stop_idx': array([0]), 'n_requests': array([2]), 'headway': array([700.5]), 'schedule_deviation': array([10])}, the model recommends action: 0

# %%
from rl_env import FlexSimEnv
import pandas as pd

# %%
def evaluate_agent(env, agent, num_episodes=10):
    """Evaluate the agent's performance in the environment."""
    results = {'pax': [], 'vehicles': [], 'state': [], 'idle': []}

    np.random.seed(0)
    for episode in range(num_episodes):
        # Initialize state tracking for each vehicle
        vehicle_observations = {}
        vehicle_actions = {}  # Track previous actions
        
        # Start the episode
        next_observation, info = env.reset()
        vehicle_idx = info['veh_idx']

        # update observation
        observation = next_observation
        vehicle_observations[vehicle_idx] = observation
        
        # select action
        action = agent.act(observation, vehicle_idx)
        vehicle_actions[vehicle_idx] = action

        # take action in environment
        next_observation, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated

        while not done:
            # Get current vehicle index
            vehicle_idx = info['veh_idx']
            
            # update observation
            observation = next_observation
            vehicle_observations[vehicle_idx] = observation

            # Select action using shared policy
            action = agent.act(observation, vehicle_idx)
            vehicle_actions[vehicle_idx] = action
            
            # Take action in environment
            next_observation, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
        # recordings
        history = env.env.get_history()
        for key in history:
            history[key]['scenario'] = 'RL'
            history[key]['episode'] = episode
            results[key].append(history[key])
    for df_key in results:
        results[df_key] = pd.concat(results[df_key])
    return results

# %%
from params import *

# %%
env = FlexSimEnv()
results = evaluate_agent(env, loaded_agent, num_episodes=40)

# %%
from utils import create_field_from_list_column

# %%
state = results['state'].copy()
state = state[state['time'].between(RESULTS_START_TIME_MINUTES*60, RESULTS_END_TIME_MINUTES*60)]
state['unweighted_rewards'] = state['unweighted_rewards'].astype(str)
create_field_from_list_column(state, 0, 'skipped_requests', field_name='unweighted_rewards')
create_field_from_list_column(state, 1, 'off_schedule_trips', field_name='unweighted_rewards')
state['weighted_reward'] = state['skipped_requests'] * -1.0 + state['off_schedule_trips'] * -4.0

# %%
state_raw = results['state'].copy()
# state_raw.groupby(['episode']).size().head() # confirm it's 65 control steps per episode
num_time_steps = 10_000
time_steps_per_episode = 65
num_episodes = int(num_time_steps/time_steps_per_episode)

# %%
num_episodes
# Out:
# 153
